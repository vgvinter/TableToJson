# %% [markdown]
# #
# # JSON structured data from tables in scientific papers

# %% [markdown]
# ## Jsonformer non-token approach for OpenAI
# #### (based on: https://github.com/1rgs/jsonformer, https://github.com/martinezpl/jsonformer/tree/add-openai)

# %%
import os
import pandas as pd
import json
import time

import openai
from IPython.display import IFrame
from IPython.display import HTML

from LLMsTablesToJson.html_table import get_driver, extract_tableSource, extract_table, quit_driver
from LLMsTablesToJson.jsonformer_non_tokens import JsonformerNoTokens, OpenAIModel, highlight_values

DATA_DIR = "your_path"
chromedriver_path = os.path.join(DATA_DIR, "chromedriver.exe")

openai.api_key = "your_openai_api_key"

# %% [markdown]
# ## Example: Ni-doped ceria anode materials for SOFCs

# %% [markdown]
# ### Get table HTML code from DOI

# %%
doi = "10.1039/D3NJ00316G"

# %%
IFrame(src="https://dx.doi.org/" + doi, width=900, height=380)
# Out:
#         <iframe
#             width="900"
#             height="380"
#             src="https://dx.doi.org/10.1039/D3NJ00316G"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
driver = get_driver(doi, chromedriver_path)
time.sleep(2)
tableSource = extract_tableSource(driver)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_108")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_109")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_110")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_111")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_112")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_113")>, <selenium.webdriver.remote.webelement.WebElement (session="427f36180aac02dcffedb8b93bff17be", element="2F15F09D44EC762FBA9C6AD1C1B8500E_element_114")>]
# number of tables = 7

# %%
table_num = 3
html_table_anodesSOFCs = extract_table(tableSource, table_num)
quit_driver(driver)

# %%
html_table_anodesSOFCs
# Out:
# '<table class="table">\n                <thead>\n                        <tr>\n                                <th>\nNi-doped ceria NPs</th>\n                                <th>\nCrystalline size <em>D</em><sub>XRD</sub> (nm)</th>\n                                <th>\nDislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>\n                                <th>\nLattice strain, <em>ε</em> = <em>β</em>/4\u2006tan\u2006<em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>\n                                <th>\nLattice constant <em>A</em> (Å)</th>\n                        </tr>\n                </thead>\n                            <tbody>\n                        <tr>\n                                <td>\nNDC1</td>\n                                <td>\n33.03</td>\n                                <td>\n9.161 × 10<sup>−4</sup></td>\n                                <td>\n3.08</td>\n                                <td>\n5.413</td>\n                        </tr>\n                        <tr>\n                                <td>\nNDC2</td>\n                                <td>\n31.29</td>\n                                <td>\n1.021 × 10<sup>−3</sup></td>\n                                <td>\n3.22</td>\n                                <td>\n5.406</td>\n                        </tr>\n                        <tr>\n                                <td>\nNDC3</td>\n                                <td>\n31.23</td>\n                                <td>\n1.025 × 10<sup>−3</sup></td>\n                                <td>\n3.70</td>\n                                <td>\n5.403</td>\n                        </tr>\n                        <tr>\n                                <td>\nNDC4</td>\n                                <td>\n33.02</td>\n                                <td>\n9.154 × 10<sup>−4</sup></td>\n                                <td>\n3.24</td>\n                                <td>\n5.407</td>\n                        </tr>\n                </tbody>\n                    </table>'

# %%
with open("html_table_anodesSOFCs.txt", "w") as file:
    file.write(html_table_anodesSOFCs)

# %% [markdown]
# ### Show table

# %%
HTML(html_table_anodesSOFCs)
# Out:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>

# %% [markdown]
# ### Convert HTML table to JSON format with openAI LLMs

# %%
json_schema_anodesSOFCs = {
    "type": "object",
    "properties": {
        "Ce-doped SOFC anodes": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "Ni-doped ceria NP": {"type": "string"},
                    "Crystalline size DXRD (nm)": {"type": "number"},
                    "Dislocation density, δ (nm−2)": {"type": "number"},
                    "Lattice strain, ε = β/4 tan θ (×10−3)": {"type": "number"},
                    "Lattice constant A (Å)": {"type": "number"},
                },
            },
        },
    },
}

# %%
with open('json_schema_anodesSOFCs.json', 'w') as file:
    json.dump(json_schema_anodesSOFCs, file)

# %%
with open("json_schema_anodesSOFCs.json") as file:
    json_schema_anodesSOFCs = json.load(file)
    file.close()

# %%
json_schema_anodesSOFCs
# Out:
# {'type': 'object',
#  'properties': {'Ce-doped SOFC anodes': {'type': 'array',
#    'items': {'type': 'object',
#     'properties': {'Ni-doped ceria NP': {'type': 'string'},
#      'Crystalline size DXRD (nm)': {'type': 'number'},
#      'Dislocation density, δ (nm−2)': {'type': 'number'},
#      'Lattice strain, ε = β/4\u2006tan\u2006θ (×10−3)': {'type': 'number'},
#      'Lattice constant A (Å)': {'type': 'number'}}}}}}

# %% [markdown]
# #### standard prompt

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_anodesSOFCs,
    text=html_table_anodesSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code:",
    temperature=0.5,
    debug=True,
    max_array_length=4,
    max_string_token_length=10,
)

print("Generating...")
result_anodesSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP":
# [generate_string] response  "NDC1", "Crystalline size
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)":
# [generate_number] response  33.03, "D
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  9.161e-4
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.08, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)":
# [generate_number] response  5.413}, {"Ni
# [generate_string] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP":
# [generate_string] response  "NDC2", "Crystalline size
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)":
# [generate_number] response  31.29, "D
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  1.021, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.22, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)":
# [generate_number] response  5.406}, {"Ni
# [generate_string] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP":
# [generate_string] response "NDC3", "Crystalline
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)":
# [generate_number] response  31.23, "D
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  1.025, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.70, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)":
# [generate_number] response  5.403}, {"Ni
# [generate_string] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP":
# [generate_string] response  "NDC4", "Crystalline size
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)":
# [generate_number] response  33.02, "D
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  9.154, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)": 9.154, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.24, "L
# [generate_number] prompt Generate a object with the following schema extracting the information from the provided table in html code:
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 9.161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 1.021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 1.025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)": 9.154, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.24, "Lattice constant A (\u00c5)":
# [generate_number] response  5.407}]}

# %%
highlight_values(result_anodesSOFCs)
# Out:
# {
#   Ce-doped SOFC anodes: [
#     {
#       Ni-doped ceria NP: "NDC1",
#       Crystalline size DXRD (nm): 33.03,
#       Dislocation density, δ (nm−2): 9.161,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.08,
#       Lattice constant A (Å): 5.413
#     },
#     {
#       Ni-doped ceria NP: "NDC2",
#       Crystalline size DXRD (nm): 31.29,
#       Dislocation density, δ (nm−2): 1.021,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.22,
#       Lattice constant A (Å): 5.406
#     },
#     {
#       Ni-doped ceria NP: "NDC3",
#       Crystalline size DXRD (nm): 31.23,
#       Dislocation density, δ (nm−2): 1.025,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.7,
#       Lattice constant A (Å): 5.403
#     },
#     {
#       Ni-doped ceria NP: "NDC4",
#       Crystalline size DXRD (nm): 33.02,
#       Dislocation density, δ (nm−2): 9.154,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.24,
#       Lattice constant A (Å): 5.407
#     }
#   ]
# }

# %%
with open('json_table_anodesSOFCs_wrong.json', 'w') as file:
    json.dump(result_anodesSOFCs, file)

# %% [markdown]
# #### improved prompt for finding numbers with specific notation

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_anodesSOFCs,
    text=html_table_anodesSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code \
(if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):",
    temperature=0.5,
    debug=True,
    max_array_length=4,
    max_string_token_length=10,
)

print("Generating...")
result_anodesSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP":
# [raw_response] {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " \"NDC1\", \"Crystalline size"
#     }
#   ],
#   "created": 1685630183,
#   "id": "cmpl-7MdhXvksSitKL4RlJOIbmqMynAf9g",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 10,
#     "prompt_tokens": 812,
#     "total_tokens": 822
#   }
# }
# [generate_string] response  "NDC1", "Crystalline size
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)":
# [generate_number] response  33.03, "D
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  0.0009161,
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.08, "L
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)":
# [generate_number] response  5.413},  {"
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP":
# [raw_response] {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " \"NDC2\", \"Crystalline size"
#     }
#   ],
#   "created": 1685630189,
#   "id": "cmpl-7MdhdRehQ0l4E2QuMFpSP5sWoHEGv",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 10,
#     "prompt_tokens": 931,
#     "total_tokens": 941
#   }
# }
# [generate_string] response  "NDC2", "Crystalline size
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)":
# [generate_number] response  31.29, "D
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  0.0011021,
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.22, "L
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)":
# [generate_number] response  5.406}, {"Ni
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP":
# [raw_response] {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " \"NDC3\", \"Crystalline size"
#     }
#   ],
#   "created": 1685630193,
#   "id": "cmpl-7MdhhrDmj7hYWxTCZUS9BFM31ImEa",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 10,
#     "prompt_tokens": 1050,
#     "total_tokens": 1060
#   }
# }
# [generate_string] response  "NDC3", "Crystalline size
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)":
# [generate_number] response  31.23, "D
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  0.0011025,
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.7, "L
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)":
# [generate_number] response  5.403}, {"Ni
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# ...
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP":
# [raw_response] {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": " \"NDC4\", \"Crystalline size"
#     }
#   ],
#   "created": 1685630198,
#   "id": "cmpl-7Mdhm4M4qz1XBn1y0MuJ7RiDFtyPY",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 10,
#     "prompt_tokens": 1169,
#     "total_tokens": 1179
#   }
# }
# [generate_string] response  "NDC4", "Crystalline size
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)":
# [generate_number] response  33.02, "D
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)":
# [generate_number] response  0.0009154,
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)": 0.0009154, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)":
# [generate_number] response  3.24, "L
# [generate_number] prompt Generate an object with the following schema extracting the information from the provided table in html code (if you find numbers as 1.025 × 10<sup>−3</sup>, this means 1.025e-3):
# <table class="table">
#                 <thead>
#                         <tr>
#                                 <th>
# Ni-doped ceria NPs</th>
#                                 <th>
# Crystalline size <em>D</em><sub>XRD</sub> (nm)</th>
#                                 <th>
# Dislocation density, <em>δ</em> (nm<sup>−2</sup>)</th>
#                                 <th>
# Lattice strain, <em>ε</em> = <em>β</em>/4 tan <em>θ</em> (×10<sup><sup>−3</sup></sup>)</th>
#                                 <th>
# Lattice constant <em>A</em> (Å)</th>
#                         </tr>
#                 </thead>
#                             <tbody>
#                         <tr>
#                                 <td>
# NDC1</td>
#                                 <td>
# 33.03</td>
#                                 <td>
# 9.161 × 10<sup>−4</sup></td>
#                                 <td>
# 3.08</td>
#                                 <td>
# 5.413</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC2</td>
#                                 <td>
# 31.29</td>
#                                 <td>
# 1.021 × 10<sup>−3</sup></td>
#                                 <td>
# 3.22</td>
#                                 <td>
# 5.406</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC3</td>
#                                 <td>
# 31.23</td>
#                                 <td>
# 1.025 × 10<sup>−3</sup></td>
#                                 <td>
# 3.70</td>
#                                 <td>
# 5.403</td>
#                         </tr>
#                         <tr>
#                                 <td>
# NDC4</td>
#                                 <td>
# 33.02</td>
#                                 <td>
# 9.154 × 10<sup>−4</sup></td>
#                                 <td>
# 3.24</td>
#                                 <td>
# 5.407</td>
#                         </tr>
#                 </tbody>
#                     </table>
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Ce-doped SOFC anodes": {"type": "array", "items": {"type": "object", "properties": {"Ni-doped ceria NP": {"type": "string"}, "Crystalline size DXRD (nm)": {"type": "number"}, "Dislocation density, \u03b4 (nm\u22122)": {"type": "number"}, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": {"type": "number"}, "Lattice constant A (\u00c5)": {"type": "number"}}}}}}
# Result: {"Ce-doped SOFC anodes": [{"Ni-doped ceria NP": "NDC1", "Crystalline size DXRD (nm)": 33.03, "Dislocation density, \u03b4 (nm\u22122)": 0.0009161, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.08, "Lattice constant A (\u00c5)": 5.413}, {"Ni-doped ceria NP": "NDC2", "Crystalline size DXRD (nm)": 31.29, "Dislocation density, \u03b4 (nm\u22122)": 0.0011021, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.22, "Lattice constant A (\u00c5)": 5.406}, {"Ni-doped ceria NP": "NDC3", "Crystalline size DXRD (nm)": 31.23, "Dislocation density, \u03b4 (nm\u22122)": 0.0011025, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.7, "Lattice constant A (\u00c5)": 5.403}, {"Ni-doped ceria NP": "NDC4", "Crystalline size DXRD (nm)": 33.02, "Dislocation density, \u03b4 (nm\u22122)": 0.0009154, "Lattice strain, \u03b5 = \u03b2/4\u2006tan\u2006\u03b8 (\u00d710\u22123)": 3.24, "Lattice constant A (\u00c5)":
# [generate_number] response  5.407}]}

# %%
highlight_values(result_anodesSOFCs)
# Out:
# {
#   Ce-doped SOFC anodes: [
#     {
#       Ni-doped ceria NP: "NDC1",
#       Crystalline size DXRD (nm): 33.03,
#       Dislocation density, δ (nm−2): 0.0009161,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.08,
#       Lattice constant A (Å): 5.413
#     },
#     {
#       Ni-doped ceria NP: "NDC2",
#       Crystalline size DXRD (nm): 31.29,
#       Dislocation density, δ (nm−2): 0.0011021,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.22,
#       Lattice constant A (Å): 5.406
#     },
#     {
#       Ni-doped ceria NP: "NDC3",
#       Crystalline size DXRD (nm): 31.23,
#       Dislocation density, δ (nm−2): 0.0011025,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.7,
#       Lattice constant A (Å): 5.403
#     },
#     {
#       Ni-doped ceria NP: "NDC4",
#       Crystalline size DXRD (nm): 33.02,
#       Dislocation density, δ (nm−2): 0.0009154,
#       Lattice strain, ε = β/4 tan θ (×10−3): 3.24,
#       Lattice constant A (Å): 5.407
#     }
#   ]
# }

# %%
with open('json_table_anodesSOFCs.json', 'w') as file:
    json.dump(result_anodesSOFCs, file)
