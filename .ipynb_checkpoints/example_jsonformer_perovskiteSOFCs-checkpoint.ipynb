# %% [markdown]
# #
# # JSON structured data from tables in scientific papers

# %% [markdown]
# ## Jsonformer non-token approach for OpenAI
# #### (based on: https://github.com/1rgs/jsonformer, https://github.com/martinezpl/jsonformer/tree/add-openai)

# %%
import os
import pandas as pd
import json
import time

import openai
from IPython.display import IFrame
from IPython.display import HTML

from TableToJson.html_table import get_driver, extract_tableSource, extract_table, quit_driver
from TableToJson.jsonformer_non_tokens import JsonformerNoTokens, OpenAIModel, highlight_values

DATA_DIR = "your_path"
chromedriver_path = os.path.join(DATA_DIR, "chromedriver.exe")

openai.api_key = "your_openai_api_key"

# %% [markdown]
# ## Example: Perovskite-structured cathode materials for SOFCs

# %% [markdown]
# ### Get table HTML code from DOI

# %%
doi = "10.1016/j.ceramint.2019.11.066"

# %%
IFrame(src="https://dx.doi.org/" + doi, width=900, height=380)
# Out:
#         <iframe
#             width="900"
#             height="380"
#             src="https://dx.doi.org/10.1016/j.ceramint.2019.11.066"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
driver = get_driver(doi, chromedriver_path)
time.sleep(2)
tableSource = extract_tableSource(driver)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3046bfe5b6cae6d1e582e99dc1e49059", element="750F9861ACDBEDA1CE99ADF8DC203A90_element_61")>, <selenium.webdriver.remote.webelement.WebElement (session="3046bfe5b6cae6d1e582e99dc1e49059", element="750F9861ACDBEDA1CE99ADF8DC203A90_element_62")>, <selenium.webdriver.remote.webelement.WebElement (session="3046bfe5b6cae6d1e582e99dc1e49059", element="750F9861ACDBEDA1CE99ADF8DC203A90_element_63")>, <selenium.webdriver.remote.webelement.WebElement (session="3046bfe5b6cae6d1e582e99dc1e49059", element="750F9861ACDBEDA1CE99ADF8DC203A90_element_64")>]
# number of tables = 4

# %%
table_num = 1
html_table_perovskiteSOFCs = extract_table(tableSource, table_num)
quit_driver(driver)

# %%
html_table_perovskiteSOFCs
# Out:
# '<table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93\u202f×\u202f10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</sp ...

# %%
with open("html_table_perovskiteSOFCs.txt", "w") as file:
    file.write(html_table_perovskiteSOFCs)

# %% [markdown]
# ### Show table

# %%
HTML(html_table_perovskiteSOFCs)
# Out:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...

# %% [markdown]
# ### Convert HTML table to JSON format with openAI LLMs

# %%
json_schema_perovskiteSOFCs = {
    "type": "object",
    "properties": {
        "Perovskite SOFC cathodes": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "Composition": {"type": "string"},
                    "𝝈𝒆  (Scm−1)": {"type": "string"},
                    "𝝈𝒊  (Scm−1)": {"type": "string"},
                    "CTE (10−6K−1)": {"type": "string"},
                    "References": {"type": "string"},
                },
            },
        },
    },
}

# %%
with open('json_schema_perovskiteSOFCs.json', 'w') as file:
    json.dump(json_schema_perovskiteSOFCs, file)

# %%
with open("json_schema_perovskiteSOFCs.json") as file:
    json_schema_perovskiteSOFCs = json.load(file)
    file.close()

# %%
json_schema_perovskiteSOFCs
# Out:
# {'type': 'object',
#  'properties': {'Perovskite SOFC cathodes': {'type': 'array',
#    'items': {'type': 'object',
#     'properties': {'Composition': {'type': 'string'},
#      '𝝈𝒆  (Scm−1)': {'type': 'string'},
#      '𝝈𝒊  (Scm−1)': {'type': 'string'},
#      'CTE (10−6K−1)': {'type': 'string'},
#      'References': {'type': 'string'}}}}}}

# %% [markdown]
# #### standard prompt

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_perovskiteSOFCs,
    text=html_table_perovskiteSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code:",
    temperature=0.5,
    debug=True,
    max_array_length=7,
    max_string_token_length=10,
)

print("Generating...")
result_perovskiteSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition":
# [generate_string] response  "La1-xSrxMnO
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "130–300", "\ud835\
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "5.93\u00d710
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11\u201313", "References":
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References":
# [generate_string] response  "[90]"}]
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition":
# [generate_string] response  "La1-xSrxCoO3
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "1200\u20131600", "\ud8
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "0.22", "CTE (10
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)":
# [generate_string] response  "19\\u201320", "References":
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\u00d710", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "\u2013", "CTE (10\
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\u00d710", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11.4", "References": "[101
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-7-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-7"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-8-Frame" tabindex="0" style="font-size: 90%; display: inline-block; position: relative;" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-8"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</td></ ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u00d710", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\u00d710", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)": "11.4", "References":
# [generate_string] response  "[101]"}]}

# %%
highlight_values(result_perovskiteSOFCs)
# Out:
# {
#   Perovskite SOFC cathodes: [
#     {
#       Composition: "La1-xSrxMnO",
#       𝝈𝒆  (Scm−1): "130–300",
#       𝝈𝒊  (Scm−1): "5.93\u00d710",
#       CTE (10−6K−1): "11\u201313",
#       References: "[90]"
#     },
#     {
#       Composition: "La1-xSrxCoO3",
#       𝝈𝒆  (Scm−1): "1200\u20131600",
#       𝝈𝒊  (Scm−1): "0.22",
#       CTE (10−6K−1): "19\\u201320",
#       References: "[91,92]"
#     },
#     {
#       Composition: "La1-xSrxFeO3",
#       𝝈𝒆  (Scm−1): "129\u2013369",
#       𝝈𝒊  (Scm−1): "0.205\\u2013 5.6",
#       CTE (10−6K−1): "12.2\\u201316.3",
#       References: "[93],[94],[95]"
#     },
#     {
#       Composition: "La1-xSrxCoFeO",
#       𝝈𝒆  (Scm−1): "87\\u20131050",
#       𝝈𝒊  (Scm−1): "0.058\\\\u2013 8",
#       CTE (10−6K−1): "14.8\\\\u201321.4",
#       References: "[96,97]"
#     },
#     {
#       Composition: "Pr1-xSrxCo1-",
#       𝝈𝒆  (Scm−1): "76\\\\u2013950",
#       𝝈𝒊  (Scm−1): "1.5\\u00d710",
#       CTE (10−6K−1): "12.8\\\\u201321.3",
#       References: "[95,98]"
#     },
#     {
#       Composition: "Sm0.5Sr0.5",
#       𝝈𝒆  (Scm−1): ">1000",
#       𝝈𝒊  (Scm−1): "–",
#       CTE (10−6K−1): "20.5",
#       References: "[99,100]"
#     },
#     {
#       Composition: "LaNi0.6Fe0.4",
#       𝝈𝒆  (Scm−1): "580",
#       𝝈𝒊  (Scm−1): "\u2013",
#       CTE (10−6K−1): "11.4",
#       References: "[101]"
#     }
#   ]
# }

# %%
with open('json_table_perovskiteSOFCs_standard.json', 'w') as file:
    json.dump(result_perovskiteSOFCs, file)

# %% [markdown]
# #### improved prompt: increase max_string_token_length to get better names

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_perovskiteSOFCs,
    text=html_table_perovskiteSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code:",
    temperature=0.5,
    debug=True,
    max_array_length=7,
    max_string_token_length=30,
)

print("Generating...")
result_perovskiteSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition":
# [generate_string] response  "La1-xSrxMnO3","σ  (Scm−1)": "130–300", "σi  (Scm−1)": "5.93×10−7", "CTE (
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "130–300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93 × 10−7", "CTE (10
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "5.93\u2009\xb7\u200910\u207b\u00b71", "CTE (10\u22126K\u22121)": "11\u201313", "References":
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11\u20133", "References": "[90]"}]
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References":
# [generate_string] response  "[90]"}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition":
# [generate_string] response  "La1-xSrxCoO3","\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\u20131600", "\ud835\ud
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "1200\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "0.22", "CTE (10\u22126K\u22121)": "19\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)":
# [generate_string] response "19\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b73", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93], [94], [95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b73", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96], [97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b7\\\\u20094.4\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b75", "CTE (10\u22126K\u22121)": ",", "References": "[95], [98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99], [100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "\u2013", "CTE (10\u22126K\u22121)": "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b73", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93], [94], [95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b73", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96], [97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b7\\\\u20094.4\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b75", "CTE (10\u22126K\u22121)": ",", "References": "[95], [98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99], [100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)":
# [generate_string] response "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\\u2009\\xb7\\u200910\\u207b\\u00b71", "CTE (10\u22126K\u22121)": "11\\u20133", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b73", "CTE (10\u22126K\u22121)": "12.2\\\\u201316.3", "References": "[93], [94], [95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b73", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\u201321.4", "References": "[96], [97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b7\\\\u20094.4\\\\\\\\u2009\\\\\\\\xb7\\\\\\\\u200910\\\\\\\\u207b\\\\\\\\u00b75", "CTE (10\u22126K\u22121)": ",", "References": "[95], [98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99], [100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)": "11.4", "References":
# [generate_string] response  "[101]"}]}

# %%
highlight_values(result_perovskiteSOFCs)
# Out:
# {
#   Perovskite SOFC cathodes: [
#     {
#       Composition: "La1-xSrxMnO3",
#       𝝈𝒆  (Scm−1): "130–300",
#       𝝈𝒊  (Scm−1): "5.93\u2009\xb7\u200910\u207b\u00b71",
#       CTE (10−6K−1): "11\u20133",
#       References: "[90]"
#     },
#     {
#       Composition: "La1-xSrxCoO3",
#       𝝈𝒆  (Scm−1): "1200\u20131600",
#       𝝈𝒊  (Scm−1): "0.22",
#       CTE (10−6K−1): "19\\u201320",
#       References: "[91],[92]"
#     },
#     {
#       Composition: "La1-xSrxFeO3",
#       𝝈𝒆  (Scm−1): "129\u2013369",
#       𝝈𝒊  (Scm−1): "0.205\\u2013 5.6\\u2009\\xb7\\u200910\\u207b\\u00b73",
#       CTE (10−6K−1): "12.2\\u201316.3",
#       References: "[93], [94], [95]"
#     },
#     {
#       Composition: "La1-xSrxCoFeO3",
#       𝝈𝒆  (Scm−1): "87\\u20131050",
#       𝝈𝒊  (Scm−1): "0.058\\\\u2013 8\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b73",
#       CTE (10−6K−1): "14.8\\\\u201321.4",
#       References: "[96], [97]"
#     },
#     {
#       Composition: "Pr1-xSrxCo1-yFeyO3",
#       𝝈𝒆  (Scm−1): "76\\\\u2013950",
#       𝝈𝒊  (Scm−1): "1.5\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b7\\u20094.4\\\\u2009\\\\xb7\\\\u200910\\\\u207b\\\\u00b75",
#       CTE (10−6K−1): ",",
#       References: "[95], [98]"
#     },
#     {
#       Composition: "Sm0.5Sr0.5CoO3",
#       𝝈𝒆  (Scm−1): ">1000",
#       𝝈𝒊  (Scm−1): "–",
#       CTE (10−6K−1): "20.5",
#       References: "[99], [100]"
#     },
#     {
#       Composition: "LaNi0.6Fe0.4O3",
#       𝝈𝒆  (Scm−1): "580",
#       𝝈𝒊  (Scm−1): "\u2013",
#       CTE (10−6K−1): "11.4",
#       References: "[101]"
#     }
#   ]
# }

# %%
with open('json_table_perovskiteSOFCs_namesOK.json', 'w') as file:
    json.dump(result_perovskiteSOFCs, file)

# %% [markdown]
# #### improved prompt:
# <br>
# increase max_string_token_length, explain in the prompt how power numbers are represented, and ask to decode Unicode characters

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_perovskiteSOFCs,
    text=html_table_perovskiteSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code, \
the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication \
sign) in your response text:",
    temperature=0.9,
    debug=True,
    max_array_length=7,
    max_string_token_length=30,
)

print("Generating...")
result_perovskiteSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition":
# [generate_string] response  "La1-xSrxMnO3", "\u03C3_e (Scm\u207B\u00B
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "130–300", "\ud835\udf48\ud835\udc8a  (Scm\u22121
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "5.93e-7", "CTE (10\u22126K\u22121)": "11\u201113
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11\u201313", "References": "[90]"},
# {"Composition": "La1-xSrxCoO3",
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References":
# [generate_string] response  "[90]"},  {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition":
# [generate_string] response  "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Sc
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "1200\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "0.22", "CTE (10\u22126K\u22121)": "19\\u201320", "References
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)":
# [generate_string] response "19\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u20135.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3\\\\\\\\u2013 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "\u2013", "CTE (10\u22126K\u22121)": "11.4", "References": "[101
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u20135.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3\\\\\\\\u2013 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code, the numbers 5.93 × 10<sup>−7</sup> are decoded as 5.93e-7, decode Unicode characters (en dash, exponent, multiplication sign) in your response text:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u20131600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u20135.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\u20131050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3\\\\\\\\u2013 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\u2013", "CTE (10\u22126K\u22121)": "11.4", "References":
# [generate_string] response  "[101]"}]}

# %%
highlight_values(result_perovskiteSOFCs)
# Out:
# {
#   Perovskite SOFC cathodes: [
#     {
#       Composition: "La1-xSrxMnO3",
#       𝝈𝒆  (Scm−1): "130–300",
#       𝝈𝒊  (Scm−1): "5.93e-7",
#       CTE (10−6K−1): "11\u201313",
#       References: "[90]"
#     },
#     {
#       Composition: "La1-xSrxCoO3",
#       𝝈𝒆  (Scm−1): "1200\u20131600",
#       𝝈𝒊  (Scm−1): "0.22",
#       CTE (10−6K−1): "19\\u201320",
#       References: "[91,92]"
#     },
#     {
#       Composition: "La1-xSrxFeO3",
#       𝝈𝒆  (Scm−1): "129\\u2013369",
#       𝝈𝒊  (Scm−1): "0.205\\u20135.6e-3",
#       CTE (10−6K−1): "12.2\\\\u201316.3",
#       References: "[93],[94],[95]"
#     },
#     {
#       Composition: "La1-xSrxCoFeO3",
#       𝝈𝒆  (Scm−1): "87\u20131050",
#       𝝈𝒊  (Scm−1): "0.058\\\\u2013 8e-3",
#       CTE (10−6K−1): "14.8\\\\\\\\u201321.4",
#       References: "[96,97]"
#     },
#     {
#       Composition: "Pr1-xSrxCo1-yFeyO3",
#       𝝈𝒆  (Scm−1): "76\\\\u2013950",
#       𝝈𝒊  (Scm−1): "1.5e-3\\\\u2013 4.4e-5",
#       CTE (10−6K−1): "12.8\\\\\\\\\\\\\\\\u201321.3",
#       References: "[95,98]"
#     },
#     {
#       Composition: "Sm0.5Sr0.5CoO3",
#       𝝈𝒆  (Scm−1): ">1000",
#       𝝈𝒊  (Scm−1): "\\u2013",
#       CTE (10−6K−1): "20.5",
#       References: "[99,100]"
#     },
#     {
#       Composition: "LaNi0.6Fe0.4O3",
#       𝝈𝒆  (Scm−1): "580",
#       𝝈𝒊  (Scm−1): "\u2013",
#       CTE (10−6K−1): "11.4",
#       References: "[101]"
#     }
#   ]
# }

# %%
with open('json_table_perovskiteSOFCs_unicode_issue.json', 'w') as file:
    json.dump(result_perovskiteSOFCs, file)

# %% [markdown]
# #### very similar prompt that worked OK this time!!

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_perovskiteSOFCs,
    text=html_table_perovskiteSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code \
(a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication \
sign) in your output:",
    temperature=0.9,
    debug=True,
    max_array_length=7,
    max_string_token_length=50,
)

print("Generating...")
result_perovskiteSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition":
# [generate_string] response  "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130–300", "\ud835\udf
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93\u00d710\u22125", "CTE
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References":
# [generate_string] response  "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600",
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition":
# [generate_string] response  "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "0.22", "CTE (10\u22126K\u22121)": "19-20", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3",
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)":
# [generate_string] response  "19-20", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19-20", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129-369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205-5.6e-3", "CTE (10\u22126K\u22121)": "12.2-16.3", "References": "[93,94,95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87-1050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058-8e-3", "CTE (10\u22126K\u22121)": "14.8-21.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76-950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3-4.4e-5", "CTE (10\u22126K\u22121)": "12.8-21.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "-", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "-", "CTE (10\u22126K\u22121)": "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19-20", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129-369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205-5.6e-3", "CTE (10\u22126K\u22121)": "12.2-16.3", "References": "[93,94,95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87-1050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058-8e-3", "CTE (10\u22126K\u22121)": "14.8-21.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76-950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3-4.4e-5", "CTE (10\u22126K\u22121)": "12.8-21.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "-", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "-", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> means 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11-13", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200-1600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19-20", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129-369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205-5.6e-3", "CTE (10\u22126K\u22121)": "12.2-16.3", "References": "[93,94,95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87-1050", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058-8e-3", "CTE (10\u22126K\u22121)": "14.8-21.4", "References": "[96,97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76-950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3-4.4e-5", "CTE (10\u22126K\u22121)": "12.8-21.3", "References": "[95,98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "-", "CTE (10\u22126K\u22121)": "20.5", "References": "[99,100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "-", "CTE (10\u22126K\u22121)": "11.4", "References":
# [generate_string] response  "[101]"}]}

# %%
highlight_values(result_perovskiteSOFCs)
# Out:
# {
#   Perovskite SOFC cathodes: [
#     {
#       Composition: "La1-xSrxMnO3",
#       𝝈𝒆  (Scm−1): "130-300",
#       𝝈𝒊  (Scm−1): "5.93e-7",
#       CTE (10−6K−1): "11-13",
#       References: "[90]"
#     },
#     {
#       Composition: "La1-xSrxCoO3",
#       𝝈𝒆  (Scm−1): "1200-1600",
#       𝝈𝒊  (Scm−1): "0.22",
#       CTE (10−6K−1): "19-20",
#       References: "[91,92]"
#     },
#     {
#       Composition: "La1-xSrxFeO3",
#       𝝈𝒆  (Scm−1): "129-369",
#       𝝈𝒊  (Scm−1): "0.205-5.6e-3",
#       CTE (10−6K−1): "12.2-16.3",
#       References: "[93,94,95]"
#     },
#     {
#       Composition: "La1-xSrxCoFeO3",
#       𝝈𝒆  (Scm−1): "87-1050",
#       𝝈𝒊  (Scm−1): "0.058-8e-3",
#       CTE (10−6K−1): "14.8-21.4",
#       References: "[96,97]"
#     },
#     {
#       Composition: "Pr1-xSrxCo1-yFeyO3",
#       𝝈𝒆  (Scm−1): "76-950",
#       𝝈𝒊  (Scm−1): "1.5e-3-4.4e-5",
#       CTE (10−6K−1): "12.8-21.3",
#       References: "[95,98]"
#     },
#     {
#       Composition: "Sm0.5Sr0.5CoO3",
#       𝝈𝒆  (Scm−1): ">1000",
#       𝝈𝒊  (Scm−1): "-",
#       CTE (10−6K−1): "20.5",
#       References: "[99,100]"
#     },
#     {
#       Composition: "LaNi0.6Fe0.4O3",
#       𝝈𝒆  (Scm−1): "580",
#       𝝈𝒊  (Scm−1): "-",
#       CTE (10−6K−1): "11.4",
#       References: "[101]"
#     }
#   ]
# }

# %%
with open('json_table_perovskiteSOFCs_best.json', 'w') as file:
    json.dump(result_perovskiteSOFCs, file)

# %% [markdown]
# #### repetition that didn't work!

# %%
builder = JsonformerNoTokens(
    model=OpenAIModel("text-davinci-003", debug=False),
    json_schema=json_schema_perovskiteSOFCs,
    text=html_table_perovskiteSOFCs,
    prompt="Generate an object with the following schema extracting the information from the provided table in html code \
(a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication \
sign) in your output:",
    temperature=0.9,
    debug=True,
    max_array_length=7,
    max_string_token_length=50,
)

print("Generating...")
result_perovskiteSOFCs = builder()
# Out:
# Generating...
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition":
# [generate_string] response  "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130-300", "\ud835\udf
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "130–300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":  "5.93e-7", "CTE (10\u22126
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "5.93e-7", "CTE (10\u22126K\u22121)": "11\u201313", "References": "[90]"}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11\u201313", "References": "[90]"},
# {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Sc
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References":
# [generate_string] response  "[90]"},  {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\u
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition":
# [generate_string] response  "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\u20131600", "\ud835\ud
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)":
# [generate_string] response  "1200\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "0.22", "CTE (10\u22126K\u22121)": "19\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)":
# [generate_string] response  "19\\u201320", "References": "[91,92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Sc
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u2013150", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96],[97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3- 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95],[98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99],[100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)":
# [generate_string] response  "\\\\u2013", "CTE (10\u22126K\u22121)": "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u2013150", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96],[97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3- 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95],[98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99],[100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\\\\\u2013", "CTE (10\u22126K\u22121)":
# [generate_string] response  "11.4", "References": "[101]"}]}
# [generate_string] prompt Generate an object with the following schema extracting the information from the provided table in html code (a number like 5.93 × 10<sup>−7</sup> should be read as 5.93e-7), decode Unicode characters (en dash, exponent, multiplication sign) in your output:
# <table><thead><tr class="rowsep-1 valign-top"><th scope="col">Composition</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-17-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>e</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.737ex" height="1.724ex" viewBox="0 -513 1178.6 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-65"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-17"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">e</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col"><span class="math"><span class="MathJax_Preview" style=""></span><span class="MathJax_SVG" id="MathJax-Element-18-Frame" tabindex="0" data-mathml="<math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;><mrow is=&quot;true&quot;><msub is=&quot;true&quot;><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>&amp;#x3C3;</mi></mrow><mrow is=&quot;true&quot;><mi mathvariant=&quot;bold-italic&quot; is=&quot;true&quot;>i</mi></mrow></msub></mrow></math>" role="presentation" style="font-size: 90%; display: inline-block; position: relative;"><svg xmlns:xlink="http://www.w3.org/1999/xlink" width="2.493ex" height="1.724ex" viewBox="0 -513 1073.2 742.1" role="img" focusable="false" style="vertical-align: -0.532ex;" aria-hidden="true"><g stroke="currentColor" fill="currentColor" stroke-width="0" transform="matrix(1 0 0 -1 0 0)"><g is="true"><g is="true"><g is="true"><g is="true"><use xlink:href="#MJMATHBI-3C3"></use></g></g><g is="true" transform="translate(686,-150)"><g is="true"><use transform="scale(0.707)" xlink:href="#MJMATHBI-69"></use></g></g></g></g></g></svg><span class="MJX_Assistive_MathML" role="presentation"><math xmlns="http://www.w3.org/1998/Math/MathML"><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></span></span><script type="math/mml" id="MathJax-Element-18"><math><mrow is="true"><msub is="true"><mrow is="true"><mi mathvariant="bold-italic" is="true">σ</mi></mrow><mrow is="true"><mi mathvariant="bold-italic" is="true">i</mi></mrow></msub></mrow></math></script></span> (Scm<sup>−1</sup>)</th><th scope="col">CTE (10<sup>−6</sup>K<sup>−1</sup>)</th><th scope="col">References</th></tr></thead><tbody><tr class="valign-top"><td class="align-left">La<sub>1-x</sub>Sr<sub>x</sub>MnO<sub>3</sub></td><td class="align-left">130–300</td><td class="align-left">5.93 × 10<sup>−7</sup></td><td class="align-left">11–13</td><td class="align-left">[<a class="anchor workspace-trigger u-display-inline anchor-paragraph" href="#bib90" name="bbib90"><span class="anchor-text">90</span></a>]</t ...
# Output result in the following JSON schema format, one value at a time,
#         do not continue the JSON:
# {"type": "object", "properties": {"Perovskite SOFC cathodes": {"type": "array", "items": {"type": "object", "properties": {"Composition": {"type": "string"}, "\ud835\udf48\ud835\udc86  (Scm\u22121)": {"type": "string"}, "\ud835\udf48\ud835\udc8a  (Scm\u22121)": {"type": "string"}, "CTE (10\u22126K\u22121)": {"type": "string"}, "References": {"type": "string"}}}}}}
# Result: {"Perovskite SOFC cathodes": [{"Composition": "La1-xSrxMnO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "130\u2013300", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "5.93e-7", "CTE (10\u22126K\u22121)": "11\\u201313", "References": "[90]"}, {"Composition": "La1-xSrxCoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "1200\\u2013600", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.22", "CTE (10\u22126K\u22121)": "19\\\\u201320", "References": "[91],[92]"}, {"Composition": "La1-xSrxFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "129\\\\u2013369", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.205\\\\u2013 5.6e-3", "CTE (10\u22126K\u22121)": "12.2\\\\\\\\u201316.3", "References": "[93],[94],[95]"}, {"Composition": "La1-xSrxCoFeO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "87\\\\u2013150", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "0.058\\\\\\\\u2013 8e-3", "CTE (10\u22126K\u22121)": "14.8\\\\\\\\\\\\\\\\u201321.4", "References": "[96],[97]"}, {"Composition": "Pr1-xSrxCo1-yFeyO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "76\\\\\\\\u2013950", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "1.5e-3- 4.4e-5", "CTE (10\u22126K\u22121)": "12.8\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\u201321.3", "References": "[95],[98]"}, {"Composition": "Sm0.5Sr0.5CoO3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": ">1000", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\u2013", "CTE (10\u22126K\u22121)": "20.5", "References": "[99],[100]"}, {"Composition": "LaNi0.6Fe0.4O3", "\ud835\udf48\ud835\udc86  (Scm\u22121)": "580", "\ud835\udf48\ud835\udc8a  (Scm\u22121)": "\\\\\\\\u2013", "CTE (10\u22126K\u22121)": "11.4", "References":
# [generate_string] response  "[101]"}]}

# %%
highlight_values(result_perovskiteSOFCs)
# Out:
# {
#   Perovskite SOFC cathodes: [
#     {
#       Composition: "La1-xSrxMnO3",
#       𝝈𝒆  (Scm−1): "130–300",
#       𝝈𝒊  (Scm−1): "5.93e-7",
#       CTE (10−6K−1): "11\u201313",
#       References: "[90]"
#     },
#     {
#       Composition: "La1-xSrxCoO3",
#       𝝈𝒆  (Scm−1): "1200\u2013600",
#       𝝈𝒊  (Scm−1): "0.22",
#       CTE (10−6K−1): "19\\u201320",
#       References: "[91],[92]"
#     },
#     {
#       Composition: "La1-xSrxFeO3",
#       𝝈𝒆  (Scm−1): "129\\u2013369",
#       𝝈𝒊  (Scm−1): "0.205\\u2013 5.6e-3",
#       CTE (10−6K−1): "12.2\\\\u201316.3",
#       References: "[93],[94],[95]"
#     },
#     {
#       Composition: "La1-xSrxCoFeO3",
#       𝝈𝒆  (Scm−1): "87\\u2013150",
#       𝝈𝒊  (Scm−1): "0.058\\\\u2013 8e-3",
#       CTE (10−6K−1): "14.8\\\\\\\\u201321.4",
#       References: "[96],[97]"
#     },
#     {
#       Composition: "Pr1-xSrxCo1-yFeyO3",
#       𝝈𝒆  (Scm−1): "76\\\\u2013950",
#       𝝈𝒊  (Scm−1): "1.5e-3- 4.4e-5",
#       CTE (10−6K−1): "12.8\\\\\\\\\\\\\\\\u201321.3",
#       References: "[95],[98]"
#     },
#     {
#       Composition: "Sm0.5Sr0.5CoO3",
#       𝝈𝒆  (Scm−1): ">1000",
#       𝝈𝒊  (Scm−1): "\\u2013",
#       CTE (10−6K−1): "20.5",
#       References: "[99],[100]"
#     },
#     {
#       Composition: "LaNi0.6Fe0.4O3",
#       𝝈𝒆  (Scm−1): "580",
#       𝝈𝒊  (Scm−1): "\\\\u2013",
#       CTE (10−6K−1): "11.4",
#       References: "[101]"
#     }
#   ]
# }
